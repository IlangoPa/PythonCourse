# %%
import pandas as pd
import pickle

from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv('50_Startups.csv')
dataset = pd.get_dummies(dataset, drop_first = True)
independent = dataset.drop(['Profit'], axis =1)
dependent = dataset['Profit']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(independent,dependent, test_size = 0.25, random_state = 0)

# %%
loadedmodel = pickle.load(open('finalizedmodel.sav','rb'))
loadedsc = pickle.load(open('scalerX.sav','rb'))
loadedscy = pickle.load(open('scalery.sav', 'rb'))

# %%
preinput = loadedsc.transform([[1300,12000,4000,0,1]])

# %%
result = loadedmodel.predict(preinput)
print (result)
# Out:
# [-1.06062696]

# %%
preoutput = loadedscy.inverse_transform(result)
preoutput
# Out:
# array([65739.32412574])
