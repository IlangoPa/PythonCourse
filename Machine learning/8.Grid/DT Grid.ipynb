# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("Test.csv")

# %%
dataset = pd.get_dummies(dataset,dtype = int, drop_first =True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error'], 
                'max_features':[None,'log2','sqrt'],
                'splitter':['best','random']}

grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit = True, verbose = 3, n_jobs = -1)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_features': [None, 'log2', 'sqrt'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re = grid.cv_results_
print(grid.best_params_)
# Out:
# {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'}

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.043363      0.005082         0.017894        0.003591
# 1        0.040967      0.004916         0.018065        0.001955
# 2        0.034935      0.004879         0.015198        0.001736
# 3        0.033544      0.003721         0.017604        0.002502
# 4        0.033235      0.007094         0.015750        0.001428
# 5        0.033680      0.004603         0.017595        0.002948
# 6        0.037178      0.004874         0.015066        0.003145
# 7        0.032006      0.005966         0.014281        0.000869
# 8        0.030972      0.004696         0.015573        0.002909
# 9        0.028239      0.003598         0.013870        0.001964
# 10       0.025207      0.002006         0.012988        0.002565
# 11       0.026813      0.002688         0.013139        0.001590
# 12       0.140212      0.013928         0.012212        0.002347
# 13       0.098924      0.010589         0.012711        0.002826
# 14       0.080005      0.008593         0.012236        0.002920
# 15       0.068506      0.008507         0.013695        0.001022
# 16       0.081372      0.009592         0.009618        0.000866
# 17       0.051653      0.001834         0.007427        0.000894
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               sqrt           best
# 5    squared_error               sqrt         random
# 6     friedman_mse               None           best
# 7     friedman_mse               None         random
# 8     friedman_mse               log2           best
# 9     friedman_mse               log2         random
# 10    friedman_mse               sqrt           best
# 11    friedman_mse               sqrt         random
# 12  absolute_error               None           best
# 13  absolute_error               None         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
# 16  absolute_error               sqrt           best
# 17  absolute_error               sqrt         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.715408
# 1   {'criterion': 'squared_error', 'max_features':...           0.731301
# 2   {'criterion': 'squared_error', 'max_features':...           0.746336
# 3   {'criterion': 'squared_error', 'max_features':...           0.682345
# 4   {'criterion': 'squared_error', 'max_features':...           0.759172
# 5   {'criterion': 'squared_error', 'max_features':...           0.650937
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.718752
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.684157
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.742476
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.714907
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.689942
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.732996
# 12  {'criterion': 'absolute_error', 'max_features'...           0.742224
# 13  {'criterion': 'absolute_error', 'max_features'...           0.673427
# 14  {'criterion': 'absolute_error', 'max_features'...           0.697563
# 15  {'criterion': 'absolute_error', 'max_features'...           0.627573
# 16  {'criterion': 'absolute_error', 'max_features'...           0.663396
# 17  {'criterion': 'absolute_error', 'max_features'...           0.745556
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.612609           0.727762           0.709506
# 1            0.614449           0.692725           0.685518
# 2            0.535116           0.790855           0.619610
# 3            0.673456           0.743180           0.646427
# 4            0.436038           0.724736           0.697823
# 5            0.548391           0.716146           0.641144
# 6            0.645272           0.733997           0.709004
# 7            0.629496           0.736615           0.691864
# 8            0.691615           0.687991           0.673774
# 9            0.577395           0.622549           0.600824
# 10           0.576243           0.440455           0.723532
# 11           0.504289           0.723644           0.667755
# 12           0.620013           0.701398           0.714510
# 13           0.654400           0.719424           0.690430
# 14           0.650517           0.740507           0.712585
# 15           0.498069           0.695842           0.654971
# 16           0.698704           0.683558           0.709016
# 17           0.584199           0.721927           0.637055
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.672264         0.687510        0.041773                7
# 1            0.748548         0.694508        0.046406                4
# 2            0.708661         0.680115        0.091814               10
# 3            0.704784         0.690038        0.032489                6
# 4            0.684401         0.660434        0.115074               14
# 5            0.721417         0.655607        0.062805               15
# 6            0.673539         0.696113        0.032275                3
# 7            0.632267         0.674880        0.040153               12
# 8            0.641686         0.687508        0.032640                8
# 9            0.651958         0.633527        0.047546               16
# 10           0.721119         0.630258        0.109051               17
# 11           0.773616         0.680460        0.094341                9
# 12           0.748270         0.705283        0.046008                2
# 13           0.716385         0.690813        0.024903                5
# 14           0.734870         0.707209        0.032279                1
# 15           0.633292         0.621949        0.066419               18
# 16           0.601312         0.671197        0.038170               13
# 17           0.709286         0.679605        0.059891               11

# %%
new_data_df = pd.DataFrame([[50,25,2,0,0]], columns=independent.columns)
result = grid.predict(new_data_df)
result
# Out:
# array([10493.9458])
