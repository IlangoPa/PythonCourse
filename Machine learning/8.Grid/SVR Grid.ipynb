# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("Test.csv")

# %%
dataset = pd.get_dummies(dataset, dtype = int, drop_first = True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

param_grid = {'kernel':['linear','poly'], 
              'C':[1000,2000,3000], 
              'gamma':['auto','scale'] }
grid = GridSearchCV(SVR(),param_grid, refit = True, verbose = 3, n_jobs = -1)
import time
start_time = time.time()
grid.fit(independent,dependent)
end_time = time.time()
print(f"GridSearchCV took {end_time - start_time} seconds to complete.")
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\Ilango\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV took 7139.049389123917 seconds to complete.

# %%
re = grid.cv_results_
print(grid.best_params_)
# Out:
# {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        1.782407      0.142064         0.035124        0.001353     1000
# 1     4358.588133   1045.059563         0.025974        0.010685     1000
# 2        1.789435      0.059447         0.036327        0.001988     1000
# 3        0.317163      0.013051         0.038538        0.002639     1000
# 4        3.089758      0.228863         0.035644        0.000739     2000
# 5     4300.175655   1111.993258         0.027985        0.007442     2000
# 6        3.008507      0.257523         0.033643        0.002979     2000
# 7        0.368850      0.016480         0.039595        0.000183     2000
# 8        5.538438      1.121267         0.034744        0.001910     3000
# 9     3564.003467    499.612937         0.025484        0.010844     3000
# 10       5.025715      1.122063         0.031497        0.000856     3000
# 11       0.398216      0.028532         0.035691        0.003313     3000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto         poly
# 2        scale       linear
# 3        scale         poly
# 4         auto       linear
# 5         auto         poly
# 6        scale       linear
# 7        scale         poly
# 8         auto       linear
# 9         auto         poly
# 10       scale       linear
# 11       scale         poly
#
#                                                params  split0_test_score  \
# 0    {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.736398
# 1      {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}         -15.085640
# 2   {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.736398
# 3     {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}          -0.080527
# 4    {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.682349
# 5      {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}         -66.911253
# 6   {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.682349
# 7     {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}          -0.020567
# 8    {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.677778
# 9      {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}        -139.542470
# 10  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.677778
# 11    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.037700
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.675162           0.680002           0.699377
# 1           -7.827515          -9.886241          -9.199449
# 2            0.675162           0.680002           0.699377
# 3           -0.028469          -0.073376          -0.086611
# 4            0.630642           0.750714           0.646368
# 5          -42.837581         -46.649358         -44.378412
# 6            0.630642           0.750714           0.646368
# 7            0.035685          -0.011468          -0.024587
# 8            0.626814           0.732806           0.633479
# 9         -248.421043        -152.372959         -67.783230
# 10           0.626814           0.732806           0.633479
# 11           0.098496           0.049291           0.035615
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.677952         0.693778        0.022955                1
# 1          -12.489637       -10.897696        2.584811               10
# 2            0.677952         0.693778        0.022955                1
# 3           -0.134493        -0.080695        0.033795                9
# 4            0.722261         0.686467        0.045056                3
# 5          -32.275513       -46.610424       11.285664               11
# 6            0.722261         0.686467        0.045056                3
# 7           -0.076360        -0.019459        0.035693                8
# 8            0.698692         0.673914        0.039876                5
# 9         -212.402074      -164.104355       62.386929               12
# 10           0.698692         0.673914        0.039876                5
# 11          -0.020924         0.040035        0.038064                7

# %%
new_data_df = pd.DataFrame([[50,25,2,0,0]], columns=independent.columns)
result = grid.predict(new_data_df)
result
# Out:
# array([10335.05108882])
